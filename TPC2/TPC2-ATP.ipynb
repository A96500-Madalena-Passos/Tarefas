# %%
def jogo2():
    print("Escolha um valor entre 0 e 100 e responda às questões colocadas pelo computador")
    encontrado=False
    
    v1=50
    count=0
    
    q1=input("O valor escolhido é o 50? s)sim  n)não:")
    if q1=="s":
        count+=1
        print ('''O valor foi encontrado
        nº de tentativas:''', count)
    
    elif q1=="n":
        var=input('''O valor escolhido é:
                      s) superior a 50
                      i) inferior a 50
                  ''')
        if var=="s":
            v=100
            while encontrado==False:
                v2=round(v1+((v-v1)/2))
                print("O valor escolhido é o",v2,"?")
                q2=input("s)sim  n)não:")
                if q2=="s":
                    encontrado==True
                    count+=1
                    print ('''O valor foi encontrado
                    nº de tentativas:''', count)
                    break
                
                elif q2=="n":
                    encontrado=False
                    count+=1
                    var1=input('''O valor escolhido é:
                      s) superior
                      i) inferior
                    ''')
                    if var1=="s":
                        v1=v2
                
                    elif var1=="i":
                        v=v2
                    
                else:
                        print ("Comando não identificado, responda com s ou n")
                        print("O valor escolhido é o",v2,"?")
                        q2=input("s)sim  n)não:")
                        
        elif var=="i":
            v=v1
            v1=0
            while encontrado==False:
                v2=round(v1+((v-v1)/2))
                print("O valor escolhido é o",v2,"?")
                q2=input("s)sim  n)não:")
                if q2=="s":
                    encontrado==True
                    count+=1
                    print ('''O valor foi encontrado
                    nº de tentativas:''', count)
                    break
                
                elif q2=="n":
                    encontrado=False
                    count+=1
                    var1=input('''O valor escolhido é:
                      s) superior
                      i) inferior
                    ''')
                    if var1=="s":
                        v1=v2
                
                    elif var1=="i":
                        v=v2
                        
                else:
                        print ("Comando não identificado, responda com s ou n")
                        print("O valor escolhido é o",v2,"?")
                        q2=input("s)sim  n)não:")
    else:
        print ("Comando não identificado, responda com s ou n")
        jogo2()
        
jogo2()
