# %%
import random

def jogo():
    f=21
    prim=input("Pretende jogar primeiro? a)sim  b)não:")
    if prim=="a":
        j=int(input("introduza um valor a jogar entre 1 e 4:"))
        
        while f>0:
            if j<1 or j>4:
                print("jogada inválida")
                j=int(input("introduza um valor a jogar entre 1 e 4:"))
            else:
                c=5-j
                print (c)
                f-=(j+c)
                if f==1:
                    print("Fósforos restantes:",f)
                    d=input('''
                            game over. Tente novamente 
                            a)Novo jogo   b)sair
                            ''')
                    if d=="a":
                        jogo()
                    else:
                        return(print("até à próxima"))
                        break
                        
                else:
                    print("Fósforos restantes:",f)
                    j=int(input("introduza um valor a jogar entre 1 e 4:"))
    elif prim=="b":
        pc=random.randint(1,4)
        print (pc)
        print ("Fósforos restantes:", f-pc)
        
        j=int(input("introduza um valor a jogar entre 1 e 4:"))
        if j<1 or j>4:
                print("jogada inválida")
                j=int(input("introduza um valor a jogar entre 1 e 4:"))
        
        f-=(pc+j)
        print("Fósforos restantes:",f)
        
        while f>0:
            if (pc+j)==5:
                pc=random.randint(1,4)
                print (pc)
                f-=pc
                print ("Fósforos restantes:", f)
                j=int(input("introduza um valor a jogar entre 1 e 4:"))
                f-=j
                print ("Fósforos restantes:", f)
                if f==1:
                    print("Fósforos restantes:",f)
                    d=input('''
                            WINNER!! Parabéns! 
                            Pretende jogar novamente?
                            a)sim  b)não
                            ''')
                    if d=="a":
                        jogo()
                    else:
                        return(print("até à próxima"))
                        break
                    
            elif (pc+j)<5:
                pc=5-(pc+j)
                print (pc)
                f-=pc
                print ("Fósforos restantes:", f)
                break
                
            else:
                pc=10-(pc+j)
                print (pc)
                f-=pc
                print ("Fósforos restantes:", f)
                break
            
        
        j=int(input("introduza um valor a jogar entre 1 e 4:"))
        
        while f>0:
            c=5-j
            print (c)
            f-=(j+c)
            if f==1:
                print("Fósforos restantes:",f)
                d=input('''
                        game over. Tente novamente 
                        a)Novo jogo   b)sair
                        ''')
                if d=="a":
                    jogo()
                else:
                    return(print("até à próxima"))
                    break
                        
            else:
                print("Fósforos restantes:",f)
                j=int(input("introduza um valor a jogar entre 1 e 4:"))
        
    else:
        print ("comando inválido, volte a selecionar a opção pretendida: a ou b")
        jogo()
        
jogo()
